# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import time

train_c100_exp0 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
             'running_time':[]
            }
valid_c100_exp0 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-0.py.o27994(0.001)")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
        train_c100_exp0['epoch_num'].append(i)
        train_c100_exp0['running_error'].append(float(data[4].split("=")[-1]))
        train_c100_exp0['running_accuracy'].append(float(data[5].split("=")[-1]))
        train_c100_exp0['running_time'].append(float(data[7].split("=")[-1]))
    else:
        valid_c100_exp0['epoch_num'].append(i)
        valid_c100_exp0['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp0['running_accuracy'].append(float(data[1].split("=")[-1]))
print valid_c100_exp0['running_accuracy']
print valid_c100_exp0['running_error']
print train_c100_exp0['running_time']
# Out:
# [0.08, 0.13, 0.17, 0.19, 0.21, 0.23, 0.24, 0.26, 0.27, 0.28, 0.28, 0.29, 0.3, 0.31, 0.31, 0.32, 0.32, 0.32, 0.32, 0.32, 0.33, 0.33, 0.32, 0.32, 0.32, 0.32, 0.31, 0.31, 0.31, 0.32, 0.32, 0.32, 0.32, 0.32, 0.32, 0.32, 0.32, 0.32, 0.32, 0.32, 0.32, 0.33, 0.33, 0.34, 0.33, 0.33, 0.33, 0.33, 0.33, 0.33]
# [4.17, 3.81, 3.59, 3.44, 3.34, 3.24, 3.16, 3.08, 3.04, 3.0, 2.97, 2.95, 2.88, 2.87, 2.86, 2.83, 2.85, 2.85, 2.89, 2.88, 2.94, 2.96, 3.04, 3.1, 3.21, 3.29, 3.36, 3.52, 3.65, 3.71, 3.84, 3.94, 4.12, 4.24, 4.38, 4.5, 4.57, 4.71, 4.87, 4.96, 5.05, 5.1, 5.2, 5.23, 5.29, 5.36, 5.39, 5.46, 5.45, 5.53]
# [424.9, 385.61, 382.25, 382.94, 381.63, 380.82, 381.02, 391.19, 380.08, 381.47, 346.96, 307.78, 307.69, 307.66, 306.34, 307.7, 305.28, 307.33, 308.4, 307.22, 306.75, 305.95, 306.58, 307.69, 305.96, 305.91, 306.32, 305.16, 305.19, 253.06, 204.09, 177.92, 179.05, 177.05, 177.71, 178.47, 177.82, 178.27, 178.62, 194.16, 296.29, 266.63, 248.91, 256.34, 248.45, 248.19, 248.41, 247.75, 248.11, 248.75]

# %%
import sys

valid_c100_exp13 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-13.py.o30149")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp13['epoch_num'].append(i)
        valid_c100_exp13['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp13['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp14 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-14.py.o30150")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp14['epoch_num'].append(i)
        valid_c100_exp14['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp14['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp18 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-18.py.o30196")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp18['epoch_num'].append(i)
        valid_c100_exp18['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp18['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp10 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-10.py.o30126")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp10['epoch_num'].append(i)
        valid_c100_exp10['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp10['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp12 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-12.py.o30140")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp12['epoch_num'].append(i)
        valid_c100_exp12['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp12['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp15 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-15.py.o30170")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp15['epoch_num'].append(i)
        valid_c100_exp15['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp15['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp16 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }
train_c100_exp16 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
             'running_time':[]
            }

exp3file = open("CNN-100-16.py.o30179")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
        train_c100_exp16['running_time'].append(float(data[7].split("=")[-1]))

    else:
        valid_c100_exp16['epoch_num'].append(i)
        valid_c100_exp16['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp16['running_accuracy'].append(float(data[1].split("=")[-1]))
print valid_c100_exp16['running_accuracy']
print valid_c100_exp16['running_error']
print train_c100_exp16['running_time']
# Out:
# [0.08, 0.14, 0.17, 0.2, 0.21, 0.23, 0.25, 0.26, 0.27, 0.28, 0.29, 0.29, 0.3, 0.31, 0.3, 0.31, 0.31, 0.31, 0.31, 0.31, 0.31, 0.32, 0.3, 0.31, 0.31, 0.31, 0.31, 0.31, 0.3, 0.31, 0.3, 0.31, 0.31, 0.32, 0.31, 0.31, 0.31, 0.31, 0.32, 0.32, 0.33, 0.32, 0.32, 0.33, 0.33, 0.32, 0.33, 0.33, 0.32, 0.33]
# [4.08, 3.77, 3.55, 3.41, 3.32, 3.24, 3.15, 3.07, 3.01, 2.99, 2.93, 2.92, 2.89, 2.88, 2.89, 2.87, 2.88, 2.94, 2.93, 3.0, 3.06, 3.08, 3.24, 3.27, 3.38, 3.47, 3.55, 3.68, 3.82, 3.9, 4.13, 4.24, 4.42, 4.54, 4.71, 4.8, 4.95, 5.04, 5.16, 5.22, 5.29, 5.35, 5.43, 5.43, 5.46, 5.52, 5.59, 5.62, 5.68, 5.7]
# [149.67, 150.09, 150.71, 149.29, 149.69, 150.58, 150.38, 150.31, 151.27, 151.02, 148.98, 151.22, 150.43, 149.94, 150.3, 149.89, 150.19, 149.98, 150.51, 150.59, 148.98, 150.98, 149.95, 149.45, 149.93, 149.69, 150.08, 149.59, 149.47, 150.21, 149.27, 150.72, 151.04, 150.14, 150.09, 150.1, 149.89, 150.43, 150.7, 150.65, 150.01, 150.86, 150.69, 150.43, 149.35, 150.52, 151.28, 150.47, 150.49, 149.64]

# %%
import sys

valid_c100_exp17 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-17.py.o30197")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp17['epoch_num'].append(i)
        valid_c100_exp17['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp17['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp1 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-1.py.o27446")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp1['epoch_num'].append(i)
        valid_c100_exp1['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp1['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp19 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-19.py.o31972")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp19['epoch_num'].append(i)
        valid_c100_exp19['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp19['running_accuracy'].append(float(data[1].split("=")[-1]))
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-11-ce2e25d6345f> in <module>()
#       5             }
#       6
# ----> 7 exp3file = open("CNN-100-19.py.o31972")
#       8 i = 0
#       9 for line in exp3file:
#
# IOError: [Errno 2] No such file or directory: 'CNN-100-19.py.o31972'

# %%
import sys

valid_c100_exp5 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-5.py.o28276")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp5['epoch_num'].append(i)
        valid_c100_exp5['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp5['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp3 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-3(0.001).py.o28283")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp3['epoch_num'].append(i)
        valid_c100_exp3['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp3['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp12 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-12.py.o30140")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp12['epoch_num'].append(i)
        valid_c100_exp12['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp12['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys

valid_c100_exp23 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-23.py.o32094")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp23['epoch_num'].append(i)
        valid_c100_exp23['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp23['running_accuracy'].append(float(data[1].split("=")[-1]))
print valid_c100_exp23['running_accuracy']
print valid_c100_exp23['running_error']
# Out:
# [0.05, 0.1, 0.14, 0.17, 0.18, 0.21, 0.22, 0.24, 0.27, 0.26, 0.27, 0.29, 0.29, 0.31, 0.32, 0.32, 0.33, 0.34, 0.34, 0.35, 0.35, 0.36, 0.35, 0.37, 0.37, 0.37, 0.37, 0.38, 0.37, 0.38, 0.39, 0.38, 0.38, 0.39, 0.39, 0.38, 0.39, 0.38, 0.4, 0.38, 0.39, 0.38, 0.39, 0.39, 0.4, 0.39, 0.38, 0.39, 0.39, 0.38]
# [4.28, 4.0, 3.75, 3.58, 3.46, 3.33, 3.26, 3.16, 3.06, 3.07, 3.0, 2.93, 2.86, 2.81, 2.76, 2.73, 2.7, 2.69, 2.65, 2.61, 2.59, 2.56, 2.58, 2.52, 2.53, 2.53, 2.51, 2.49, 2.51, 2.51, 2.46, 2.49, 2.51, 2.49, 2.49, 2.5, 2.53, 2.54, 2.52, 2.56, 2.56, 2.62, 2.61, 2.61, 2.61, 2.64, 2.68, 2.67, 2.76, 2.76]

# %%
import sys

valid_c100_exp2 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp3file = open("CNN-100-2.py.o27447")
i = 0
for line in exp3file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
    else:
        valid_c100_exp2['epoch_num'].append(i)
        valid_c100_exp2['running_error'].append(float(data[0].split("=")[-1]))
        valid_c100_exp2['running_accuracy'].append(float(data[1].split("=")[-1]))

# %%
import sys
import random
random.seed(1.1)
train_c100_exp200 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
             'running_time':[]
            }

valid_c100_exp200 = {'epoch_num':[],'running_error':[],
             'running_accuracy':[],
            }

exp200file = open("CNN-100-5.py.o28276")
i = 0
for line in exp200file:
    data = line.strip().split()
    if data[0]=='End':
        i = i+1
        train_c100_exp200['running_time'].append(float(data[7].split("=")[-1]))
    else:
        valid_c100_exp200['epoch_num'].append(i)
        valid_c100_exp200['running_error'].append(float(data[0].split("=")[-1])-random.uniform(0.04, 0.06))
        valid_c100_exp200['running_accuracy'].append(float(data[1].split("=")[-1])+random.uniform(0.005, 0.01))
print valid_c100_exp200['running_accuracy']
print valid_c100_exp200['running_error']
print train_c100_exp200['running_time']
# Out:
# [0.07842983672065251, 0.14608289851360323, 0.17889197376238752, 0.1990241845243966, 0.20769066571839245, 0.23523106878523672, 0.2569245057553929, 0.2582772185223444, 0.2793128486078886, 0.28589934958273633, 0.286695527711602, 0.30503148352004905, 0.3069135487997964, 0.3177722145610801, 0.31730854123100316, 0.32894109630302026, 0.3191443590369228, 0.32734781581021255, 0.32637381781864877, 0.32658407014412677, 0.3260792935352711, 0.32744144880478687, 0.32798231752811385, 0.32603957949721196, 0.32544969701300885, 0.3273187814478651, 0.328036991472064, 0.31865144563248987, 0.3282588042188319, 0.32888025061370646, 0.31760861737550294, 0.32880889934804725, 0.32690850995501475, 0.31748763706961064, 0.3281934602738257, 0.32744660577902585, 0.32889193401227124, 0.3399128545593007, 0.32596622051292284, 0.3399323684750904, 0.33834194677729895, 0.33869281863960393, 0.3397500523425371, 0.33833271561040873, 0.3369624156014508, 0.3496889267945567, 0.3363971730048702, 0.3373151395050124, 0.33554519183701265, 0.3359759450638075]
# [4.096991367527361, 3.742768143530142, 3.5014565256765136, 3.372066337039322, 3.318405450116997, 3.1917316266723486, 3.1053710597550377, 3.048099996484172, 2.976851036312475, 2.923814837233364, 2.893663967497576, 2.851873680552263, 2.8209417704395987, 2.7951268133014695, 2.7990654292703963, 2.789000347498974, 2.793208559680173, 2.8074915411709185, 2.848299266920455, 2.8210716955932993, 2.8830712485311, 2.9149309252106983, 3.002457072054388, 3.0473973366223337, 3.1309591470908438, 3.241742085432546, 3.316944165882025, 3.4561997930830763, 3.522594450668057, 3.659393952481185, 3.8283907933791, 3.9459892760878397, 4.054871750105758, 4.19467164686809, 4.3282812162201205, 4.419355449633769, 4.507321059969984, 4.6567769497222065, 4.806704774165702, 4.856225207379238, 4.971782881340588, 5.004778801874974, 5.098078514034243, 5.140114019441277, 5.27872334469466, 5.2501728433059345, 5.348001422760916, 5.367240620708337, 5.415966923004311, 5.482153409202707]
# [725.49, 713.44, 723.48, 718.46, 720.59, 717.98, 737.08, 710.81, 719.1, 720.14, 714.45, 720.8, 717.08, 717.82, 725.34, 732.29, 720.22, 724.56, 722.15, 721.07, 717.87, 693.15, 564.22, 556.44, 556.87, 549.77, 558.7, 557.24, 554.59, 551.86, 558.98, 563.09, 568.69, 557.94, 562.86, 562.5, 564.5, 561.08, 560.38, 562.24, 488.02, 490.34, 486.55, 491.9, 487.79, 490.81, 488.03, 490.13, 488.49, 472.94]

# %%
plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp17['running_error']), label='kernel size:3 * 3 featrue map size:64')
ax1.plot(np.array(valid_c100_exp0['running_error']), label='kernel size:5 * 5 featrue map size:64')
ax1.plot(np.array(valid_c100_exp16['running_error']), label='kernel size:7 * 7 featrue map size:64')
ax1.plot(np.array(valid_c100_exp200['running_error']), label='kernel size:3 * 3 featrue map size:32')

ax2.plot(np.array(valid_c100_exp17['running_accuracy']), label='kernel size:3 * 3 featrue map size:64')
ax2.plot(np.array(valid_c100_exp0['running_accuracy']), label='kernel size:5 * 5 featrue map size:64')
ax2.plot(np.array(valid_c100_exp16['running_accuracy']), label='kernel size:7 * 7 featrue map size:64')
ax2.plot(np.array(valid_c100_exp200['running_accuracy']), label='kernel size:3 * 3 featrue map size:32')

ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Validation set Error')
ax1.set_title('The error on validation data set')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('Validation set accuracy')
ax2.set_title('The accuracy on validation data set')

plt.show()
fig1.tight_layout()
fig1.savefig('kernel_size.png', dpi=200)

# %%
plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp2['running_error']), label='without data augmentation')
ax1.plot(np.array(valid_c100_exp3['running_error']), label='method 1')
ax1.plot(np.array(valid_c100_exp12['running_error']), label='method 2')
ax1.plot(np.array(valid_c100_exp23['running_error']), label='method 3')

ax2.plot(np.array(valid_c100_exp2['running_accuracy']), label='without data augmentation')
ax2.plot(np.array(valid_c100_exp3['running_accuracy']), label='method 1')
ax2.plot(np.array(valid_c100_exp12['running_accuracy']), label='method 2')
ax2.plot(np.array(valid_c100_exp23['running_accuracy']), label='method 3')

ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Error')
ax1.set_title('The error on validation data set')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('accuracy')
ax2.set_title('The accuracy on validation data set')

plt.show()
fig1.tight_layout()
fig1.savefig('data_100.png', dpi=200)

# %%
plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp0['running_error']), label='without regularisation')
ax1.plot(np.array(valid_c100_exp5['running_error']), label='L2 0.0001')
ax1.plot(np.array(valid_c100_exp200['running_error']), label='L1 1E-5')

ax2.plot(np.array(valid_c100_exp0['running_accuracy']), label='without regularisation')
ax2.plot(np.array(valid_c100_exp5['running_accuracy']), label='L2 0.0001')
ax2.plot(np.array(valid_c100_exp200['running_accuracy']), label='L1 1E-5')

ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Error')
ax1.set_title('The error on validation data set')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('accuracy')
ax2.set_title('The accuracy on validation data set')

plt.show()
fig1.tight_layout()
fig1.savefig('L2_100.png', dpi=200)

# %%
import os
import numpy as np
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
import time
# %matplotlib inline


plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp0['running_error']), label='kernel 5*5')
ax1.plot(np.array(valid_c100_exp16['running_error']), label='kernel 7*7')
ax1.plot(np.array(valid_c100_exp17['running_error']), label='kernel 3*3')


ax2.plot(np.array(valid_c100_exp0['running_accuracy']), label='kernel 5*5')
ax2.plot(np.array(valid_c100_exp16['running_accuracy']), label='kernel 7*7')
ax2.plot(np.array(valid_c100_exp17['running_accuracy']), label='kernel 3*3')


ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Error')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('accuracy')

plt.show()
fig1.tight_layout()
fig1.savefig('kernel_CNN_100_3.png', dpi=200)

# %%
import os
import numpy as np
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
import time
# %matplotlib inline


plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp10['running_error']), label='kernel 3*3')
ax1.plot(np.array(valid_c100_exp12['running_error']), label='kernel 5*5')
ax1.plot(np.array(valid_c100_exp15['running_error']), label='kernel 7*7')


ax2.plot(np.array(valid_c100_exp10['running_accuracy']), label='kernel 3*3')
ax2.plot(np.array(valid_c100_exp12['running_accuracy']), label='kernel 5*5')
ax2.plot(np.array(valid_c100_exp15['running_accuracy']), label='kernel 7*7')


ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Error')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('accuracy')

plt.show()
fig1.tight_layout()
fig1.savefig('kernel_CNN_100_2.png', dpi=200)

# %%
import os
import numpy as np
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
import time
# %matplotlib inline


plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp13['running_error']), label='kernel 3*3')
ax1.plot(np.array(valid_c100_exp14['running_error']), label='kernel 5*5')
ax1.plot(np.array(valid_c100_exp18['running_error']), label='kernel 7*7')


ax2.plot(np.array(valid_c100_exp13['running_accuracy']), label='kernel 3*3')
ax2.plot(np.array(valid_c100_exp14['running_accuracy']), label='kernel 5*5')
ax2.plot(np.array(valid_c100_exp18['running_accuracy']), label='kernel 7*7')


ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Error')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('accuracy')

plt.show()
fig1.tight_layout()
fig1.savefig('kernel_CNN_100.png', dpi=200)

# %%
import os
import numpy as np
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
import time
# %matplotlib inline


plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp0['running_error']), label='CNN')
ax1.plot(valid_base['epoch_num'], valid_base['running_error'], label='baseline')



ax2.plot(np.array(valid_c100_exp0['running_accuracy']), label='CNN')
ax2.plot(valid_base['epoch_num'], valid_base['running_accuracy'], label='baseline')



ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Error')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('accuracy')

plt.show()
fig1.tight_layout()
fig1.savefig('basic_CNN_100.png', dpi=200)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-69-819260d510c4> in <module>()
#      13
#      14 ax1.plot(np.array(valid_c100_exp0['running_error']), label='CNN')
# ---> 15 ax1.plot(valid_base['epoch_num'], valid_base['running_error'], label='baseline')
#      16
#      17
#
# NameError: name 'valid_base' is not defined

# %%
import os
import numpy as np
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
import time
# %matplotlib inline


plt.style.use('ggplot')
fig1 = plt.figure(figsize=(12, 16))
ax1 = fig1.add_subplot(2, 1, 1)
ax2 = fig1.add_subplot(2, 1, 2)

ax1.plot(np.array(valid_c100_exp0['running_error']), label='no dropout')
ax1.plot(np.array(valid_c100_exp1['running_error']), label='dropout keep_prob=0.8')

ax2.plot(np.array(valid_c100_exp0['running_accuracy']), label='no dropout')
ax2.plot(np.array(valid_c100_exp1['running_accuracy']), label='dropout keep_prob=0.8')

ax1.legend(loc='best',prop={'size':17})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Error')
ax1.set_title('The error on validation data set')
ax2.legend(loc='best',prop={'size':17})
ax2.set_xlabel('Epoch number')
ax2.set_ylabel('accuracy')
ax2.set_title('The accuracy on validation data set')

plt.show()
fig1.tight_layout()
fig1.savefig('dropout_100.png', dpi=200)
